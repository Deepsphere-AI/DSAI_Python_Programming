# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepsphere-AI/DSAI_Python_Programming/blob/main/Unit-14/Python%20for%20Computer%20Vision/Program%20294-%20CSLAB_COMPUTER_VISION_IMAGE_TRANSLATION_OPENCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# *********************************************************************************************************************
  
  # File Name 	:   CSLAB_COMPUTER_VISION_IMAGE_TRANSLATION_OPENCV
  # Purpose 	:   A Program in Python using Computer Vision for Image Translation
  # Author	:   Deepsphere.ai
  # Reviewer 	:   Jothi Periasamy
  # Date 	:   10/28/2022
  # Version	:   1.0	
  
# ***********************************************************************************************************************

## Program Description : Program for Image Translation using Opencv in Python

## Python Development Environment & Runtime - Python, Anaconda

import cv2

from google.colab.patches import cv2_imshow

import numpy as np

from google.colab import drive

drive.mount('/content/drive')

vAR_CSLAB_Birds_Image = cv2.imread('/content/drive/MyDrive/Semester-4/Introduction to Computer Vision/Data/Birds.jpg')

vAR_CSLAB_img = cv2.imread('/content/drive/MyDrive/Semester-4/Introduction to Computer Vision/Data/Birds.jpg') 
  
try: 
    vAR_CSLAB_img = cv2.imread('/content/drive/MyDrive/Semester-4/Introduction to Computer Vision/Data/Birds.jpg') 
  
    (vAR_CSLAB_height, vAR_CSLAB_width) = vAR_CSLAB_img.shape[:2] 

    vAR_CSLAB_quarter_height, vAR_CSLAB_quarter_width = vAR_CSLAB_height / 4, vAR_CSLAB_width / 4

    vAR_CSLAB_Translated = np.float32([[1, 0, vAR_CSLAB_quarter_width], [0, 1, vAR_CSLAB_quarter_height]])

    vAR_CSLAB_img_translation = cv2.warpAffine(vAR_CSLAB_img, vAR_CSLAB_Translated, (vAR_CSLAB_width, vAR_CSLAB_height))

    cv2.imwrite('/content/drive/MyDrive/Semester-4/Introduction to Computer Vision/Data/Birds_Translated.jpg', vAR_CSLAB_img_translation)

    vAR_CSLAB_img = cv2.imread('/content/drive/MyDrive/Semester-4/Introduction to Computer Vision/Data/Birds_Translated.jpg')

    cv2_imshow(vAR_CSLAB_img) 

except IOError: 
    
    print ('Error while reading files !!!') 

# ****************************************************************************************************************************
#   Disclaimer.

# We are providing this code block strictly for learning and researching, this is not a production
# ready code. We have no liability on this particular code under any circumstances; users should use
# this code on their own risk. All software, hardware and othr products that are referenced in these 
# materials belong to the respective vendor who developed or who owns this product.

# ****************************************************************************************************************************
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=1140x550 at 0x7FE35C5C3B50>
